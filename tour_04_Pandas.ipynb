# %% [markdown]
# # Pandas Basics
# pandas takes different datatypes
# - pandas handles dataframes (df) - explore, clean, process tabular data
# - supports: csv, excel, sql, json, parquet... import with read_*
# - slicing, selecting, filtering w. conditions
# - plotting: scatter, var, boxplot
# - basic statistics: mean, median, min/max, counts
# - structure datatables w. melt() and pivot()
# - concatenate column and row wise to combine multiple tables
# - times-series
# - clean textual data and extract information

# %%
import pandas as pd
import numpy as np
import statistics as st

# %% [markdown]
# ## create a dataframe

# %% [markdown]
# columnwise

# %%
df1 = pd.DataFrame(
{"a" : [1 ,4, 7],       # col a
 "b" : [2, 5, 8],       # col b
 "c" : [3, 6, 9]},    
index = [1, 2, 3])      # row index

df1
# Out:
#    a  b  c
# 1  1  2  3
# 2  4  5  6
# 3  7  8  9

# %% [markdown]
# rowwise

# %%
df2 = pd.DataFrame(
[[1, 2, 3],      # row 1
[4, 5, 6],       # row 2
[7, 8, 9]], 
index=[1, 2, 3], 
columns=['a', 'b', 'c'])   # column names

df2
# Out:
#    a  b  c
# 1  1  2  3
# 2  4  5  6
# 3  7  8  9

# %% [markdown]
# ## read data

# %%
pd.read_csv(filename)                             # From a CSV file
pd.read_table(filename)                         # From a delimited text file (like TSV)
pd.read_excel(filename)                         # From an Excel file
pd.read_sql(query, connection_object)       # Read from a SQL table/database
pd.read_json(json_string)                       # Read from a JSON formatted string, URL or file.
pd.read_html(url)                                     # Parses an html URL, string or file and extracts tables to a list of dataframes
pd.read_clipboard()                                 # Takes the contents of your clipboard and passes it to read_table()
pd.DataFrame(dict)                                  # From a dict, keys for columns names, values for data as lists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5564/1236086260.py in <module>
# ----> 1 pd.read_csv(filename)                             # From a CSV file
#       2 pd.read_table(filename)                         # From a delimited text file (like TSV)
#       3 pd.read_excel(filename)                         # From an Excel file
#       4 pd.read_sql(query, connection_object)       # Read from a SQL table/database
#       5 pd.read_json(json_string)                       # Read from a JSON formatted string, URL or file.
#
# NameError: name 'filename' is not defined

# %% [markdown]
# ## Exporting Data
# Use these commands to export a DataFrame to CSV, .xlsx, SQL, or JSON.

# %%
df.to_csv(filename)                            # Write to a CSV file
df.to_excel(filename)                          # Write to an Excel file
df.to_sql(table_name, connection_object)       # Write to a SQL table
df.to_json(filename)                           # Write to a file in JSON format

# %% [markdown]
# ## Inspecting Data
# Use these commands to take a look at specific sections of your pandas DataFrame or Series.

# %%
print(df2.head(2))                        # First n rows of the DataFrame
print(df2.tail(3))                        # Last n rows of the DataFrame
print(df.shape)                           # Number of rows and columns
print(df.info())                          # Index, Datatype and Memory information
print(df.describe())                      # Summary statistics for numerical columns
print(s.value_counts(dropna=False))       # View unique values and counts
print(df.apply(pd.Series.value_counts))   # Unique values and counts for all columns

# %%
df.info
# Out:
# <bound method DataFrame.info of                 Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 0           Afghanistan          1          1                          151.0
# 1               Albania          2          2                           27.0
# 2               Algeria          3          3                            6.0
# 3               Andorra          4          2                            NaN
# 4                Angola          5          3                          146.0
# ..                  ...        ...        ...                            ...
# 197             Vietnam        198          6                           25.0
# 198  West Bank and Gaza        199          1                            NaN
# 199               Yemen        200          1                           83.0
# 200              Zambia        201          3                          161.0
# 201            Zimbabwe        202          3                          101.0
#
#      Adult literacy rate (%)  \
# 0                       28.0
# 1                       98.7
# 2                       69.9
# 3                        NaN
# 4                       67.4
# ..                       ...
# 197                     90.3
# 198                      NaN
# 199                     54.1
# 200                     68.0
# 201                     89.5
#
#      Gross national income per capita (PPP international $)  \
# 0                                                  NaN
# 1                                               6000.0
# 2                                               5940.0
# 3                                                  NaN
# 4                                               3890.0
# ..                                                 ...
# 197                                             2310.0
# 198                                                NaN
# 199                                             2090.0
# 200                                             1140.0
# 201                                                NaN
#
#      Net primary school enrolment ratio female (%)  \
# 0                                              NaN
# 1                                             93.0
# 2                                             94.0
# 3                                             83.0
# 4                                             49.0
# ..                                             ...
# 197                                           91.0
# 198                                            NaN
# 199                                           65.0
# 200                                           94.0
# 201                                           88.0
#
#      Net primary school enrolment ratio male (%)  \
# 0                                            NaN
# 1                                           94.0
# 2                                           96.0
# 3                                           83.0
# 4                                           51.0
# ..                                           ...
# 197                                         96.0
# 198                                          NaN
# 199                                         85.0
# 200                                         90.0
# 201                                         87.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 0                            26088.0                                4.0  ...
# 1                             3172.0                                0.6  ...
# 2                            33351.0                                1.5  ...
# 3                               74.0                                1.0  ...
# 4                            16557.0                                2.8  ...
# ..                               ...                                ...  ...
# 197                          86206.0                                1.4  ...
# 198                              NaN                                NaN  ...
# 199                          21732.0                                3.0  ...
# 200                          11696.0                                1.9  ...
# 201                          13228.0                                0.8  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 0                 692.50           NaN             NaN
# 1                3499.12  4.790000e+09           78.14
# 2              137535.56  6.970000e+10          351.36
# 3                    NaN           NaN             NaN
# 4                8991.46  1.490000e+10           27.13
# ..                   ...           ...             ...
# 197            101826.23  4.480000e+10           47.11
# 198               655.86  3.780000e+09             NaN
# 199             20148.34  1.150000e+10          114.52
# 200              2366.94  4.090000e+09           10.41
# 201             11457.33  5.620000e+09            3.39
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 0                                 NaN                         257.00
# 1                       -2.040000e+09                          18.47
# 2                        4.700000e+09                          40.00
# 3                                 NaN                            NaN
# 4                        9.140000e+09                         164.10
# ..                                ...                            ...
# 197                     -1.940000e+09                          20.20
# 198                               NaN                          28.00
# 199                      8.310000e+08                          82.40
# 200                     -4.470000e+08                         175.30
# 201                     -1.710000e+08                         106.50
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 0                             231.9                     257.00
# 1                              15.5                      18.47
# 2                              31.2                      40.00
# 3                               NaN                        NaN
# 4                             242.5                     164.10
# ..                              ...                        ...
# 197                            23.4                      20.20
# 198                            25.8                      28.00
# 199                            87.9                      82.40
# 200                           163.8                     175.30
# 201                            67.0                     106.50
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 0           5740436.0                     5.44                           22.9
# 1           1431793.9                     2.21                           45.4
# 2          20800000.0                     2.61                           63.3
# 3                 NaN                      NaN                            NaN
# 4           8578749.0                     4.14                           53.3
# ..                ...                      ...                            ...
# 197        21900000.0                     2.90                           26.4
# 198         2596216.0                     3.33                           71.6
# 199         5759120.5                     4.37                           27.3
# 200         4017411.0                     1.95                           35.0
# 201         4709965.0                     1.90                           35.9
#
# [202 rows x 358 columns]>

# %% [markdown]
# ## Showing Data
# option_context() - do it only within the context manager scope
#
# and set_option() - changes the settings
#
# pd.reset_option(‘all’) - used to reset all the changes.

# %%
with pd.option_context('display.max_rows', None,'display.max_columns', None,
    'display.precision', 3, ):

# %%
# Permanently changes the pandas settings
# Default value of display.max_rows is 10 i.e. at max 10 rows will be printed.
# Set it None to display all rows in the dataframe
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# All dataframes hereafter reflect these changes.
print(df)

# Resets the options
pd.reset_option('all')

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Data Cleaning
# Use these commands to perform a variety of data cleaning tasks.

# %%
df.columns = ['a','b','c']                      # Rename columns
pd.isnull()                                      # Checks for null Values, Returns Boolean Arrray
pd.notnull()                                    # Opposite of pd.isnull()
df.dropna()                                     # Drop all rows that contain null values
df.dropna(axis=1)                               # Drop all columns that contain null values
df.dropna(axis=1,thresh=2)                      # Drop all rows that have less than 2 non null values
df.fillna(x)                                    # Replace all null values with x
s.fillna(s.mean())                              # Replace all null values with the mean (mean can be replaced with almost any function from the statistics module)
s.astype(float)                                 # Convert the datatype of the series to float
s.replace(1,'one')                              # Replace all values equal to 1 with 'one'
s.replace([1,3],['one','three'])                # Replace all 1 with 'one' and 3 with 'three'
df.rename(columns={'old_name': 'new_ name'})    # Selective renaming
df.set_index('column_one')                      # Change the index
df.rename(columns=lambda x: x + 1)              # Mass renaming of columns
df.rename(index=lambda x: x + 1)                # Mass renaming of index

# %% [markdown]
# ## Selection, filter, sort & group
# Use these commands to select a specific subset of your data.

# %%
print(df3)
print(df3[0])         # Returns column with label col as Series
print(df3[[0, 1]])    # Returns columns as a new DataFrame
print(s)
print(s.iloc[3])      # Selection by position
print(s.loc['1'])     # Selection by index
print(df)
print(df.iloc[0,:])     # First row
print(df.iloc[0,0])     # First element of first column

# %%
df = pd.DataFrame(np.random.rand(20,5), columns=list("ABCDE")) # 5 columns and 20 rows of random floats
print(df)

df[df["A"] > 0.5]                           # Rows where the column A is greater than 0.5
df[(df["A"] > 0.6) & (df["A"] < 0.9)]      # Rows where 0.7 > A > 0.5
df.sort_values("A")                        # Sort values by col1 in ascending order
df.sort_values("A", ascending=False)       # Sort values by col2 in descending ordeprintr
df.sort_values(["A","B"],ascending=[True,False]) # Sort values by A in ascending order then B in descending order
df.groupby("A")                    # Returns a groupby object for values from one column
df.groupby(["A","B"])            # Returns groupby object for values from multiple columns
df.groupby("A")["B"]               # Returns the mean of the values in col2, grouped by the values in col1 (mean can be replaced with almost any function from the statistics module)

# Create a pivot table that groups by A and calculates the mean of B and C
print(df.pivot_table(index="A", values=["B", "C"], aggfunc=st.mean))

# Find the average across all columns for every unique col1 group
print(df.groupby("A").agg(np.mean))

print(df)
print(df.apply(np.mean))  # Apply the function np.mean() across each column
print(df.apply(np.max, axis=1))  # Apply the function np.max() across each row

df01 = pd.DataFrame(np.random.randint(0, 11, size=(4, 5)))
df02 = pd.DataFrame(np.random.randint(11, 21, size=(4, 5)))

# %%
df2[::2] # select every second row
# Out:
# category              A                   B                   C            \
# type                one       two       one       two       one       two
# bloodtype sex
# X         men  0.351965 -0.068066  1.757515  1.976466  0.178422  1.534688
# Y         men -2.656323 -0.074661 -1.133029 -0.951994  0.393086 -0.583531
# Z         men  0.600243 -0.430237 -1.385815 -1.114507  2.236855 -0.223956
#
# category              D
# type                one       two
# bloodtype sex
# X         men -2.283646 -0.665094
# Y         men -2.800236 -0.510031
# Z         men  0.314527 -0.188958

# %%
df2[::-1] # slelect from bottom to top
# Out:
# category                A                   B                   C            \
# type                  one       two       one       two       one       two
# bloodtype sex
# Z         women -0.198674 -1.399947  0.387080 -0.485106  1.156633  0.034137
#           men    0.600243 -0.430237 -1.385815 -1.114507  2.236855 -0.223956
# Y         women -0.971116 -0.672203 -1.340358 -0.088891  1.329186 -0.961857
#           men   -2.656323 -0.074661 -1.133029 -0.951994  0.393086 -0.583531
# X         women -0.633323 -0.408033  0.737679 -0.406095 -0.961680  0.360887
#           men    0.351965 -0.068066  1.757515  1.976466  0.178422  1.534688
#
# category                D
# type                  one       two
# bloodtype sex
# Z         women  0.067610 -0.092273
#           men    0.314527 -0.188958
# Y         women  0.003222 -0.542861
#           men   -2.800236 -0.510031
# X         women -0.620939 -0.653238
#           men   -2.283646 -0.665094

# %% [markdown]
# ### Join/Combine
# Use these commands to combine multiple dataframes into a single one.

# %%
print(df01.append(df02))                # Add the rows in df01 to the end of df02 (columns should be identical)
print(pd.concat([df01, df02],axis=1))   # Add the columns in df01 to the end of df02 (rows should be identical)

#SQL-style join the columns in df01 with the columns on df02 where
#the rows for col have identical values. 'how' can be one of 'left', 'right', 'outer', 'inner'
print(df01.join(df02,on=col1 ,how='inner'))

# %%
df.dtypes    # shows the datatypes in the df also df.info, df.columns
# Out:
# Country                            object
# CountryID                           int64
# Continent                           int64
# Adolescent fertility rate (%)     float64
# Adult literacy rate (%)           float64
#                                    ...
# Under_five_mortality_from_IHME    float64
# Under_five_mortality_rate         float64
# Urban_population                  float64
# Urban_population_growth           float64
# Urban_population_pct_of_total     float64
# Length: 358, dtype: object

# %% [markdown]
# ### filter columns

# %%
df.Country    # for column names w/o a space in it
df["Adult literacy rate (%)"]  # for columns w space in its name
# Out:
# 0      28.0
# 1      98.7
# 2      69.9
# 3       NaN
# 4      67.4
#        ...
# 197    90.3
# 198     NaN
# 199    54.1
# 200    68.0
# 201    89.5
# Name: Adult literacy rate (%), Length: 202, dtype: float64

# %%
df[["Country", "Adult literacy rate (%)"]]  # double brackets
# Out:
#                 Country  Adult literacy rate (%)
# 0           Afghanistan                     28.0
# 1               Albania                     98.7
# 2               Algeria                     69.9
# 3               Andorra                      NaN
# 4                Angola                     67.4
# ..                  ...                      ...
# 197             Vietnam                     90.3
# 198  West Bank and Gaza                      NaN
# 199               Yemen                     54.1
# 200              Zambia                     68.0
# 201            Zimbabwe                     89.5
#
# [202 rows x 2 columns]

# %%
df.Continent.unique() # uniques in a col
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %% [markdown]
# ### filter - boolean indexing

# %%
df[df["Adult literacy rate (%)"] < 40]
# Out:
#           Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 0     Afghanistan          1          1                          151.0
# 18          Benin         19          3                          108.0
# 27   Burkina Faso         28          3                          131.0
# 34           Chad         35          3                          193.0
# 58       Ethiopia         59          3                          109.0
# 71         Guinea         72          3                          153.0
# 110          Mali        111          3                          192.0
# 122    Mozambique        123          3                          185.0
# 132         Niger        133          3                          199.0
# 158       Senegal        159          3                          100.0
# 161  Sierra Leone        162          3                          178.0
#
#      Adult literacy rate (%)  \
# 0                       28.0
# 18                      34.7
# 27                      23.6
# 34                      25.7
# 58                      35.9
# 71                      29.5
# 110                     24.0
# 122                     38.7
# 132                     28.7
# 158                     39.3
# 161                     34.8
#
#      Gross national income per capita (PPP international $)  \
# 0                                                  NaN
# 18                                              1250.0
# 27                                              1130.0
# 34                                              1170.0
# 58                                               630.0
# 71                                              1130.0
# 110                                             1000.0
# 122                                              660.0
# 132                                              630.0
# 158                                             1560.0
# 161                                              610.0
#
#      Net primary school enrolment ratio female (%)  \
# 0                                              NaN
# 18                                            73.0
# 27                                            42.0
# 34                                            49.0
# 58                                            68.0
# 71                                            66.0
# 110                                           54.0
# 122                                           73.0
# 132                                           37.0
# 158                                           70.0
# 161                                           36.0
#
#      Net primary school enrolment ratio male (%)  \
# 0                                            NaN
# 18                                          87.0
# 27                                          52.0
# 34                                          71.0
# 58                                          74.0
# 71                                          77.0
# 110                                         67.0
# 122                                         79.0
# 132                                         50.0
# 158                                         71.0
# 161                                         50.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 0                            26088.0                                4.0  ...
# 18                            8760.0                                3.1  ...
# 27                           14359.0                                3.0  ...
# 34                           10468.0                                3.1  ...
# 58                           81021.0                                2.5  ...
# 71                            9181.0                                2.0  ...
# 110                          11968.0                                3.0  ...
# 122                          20971.0                                2.1  ...
# 132                          13737.0                                3.5  ...
# 158                          12072.0                                2.5  ...
# 161                           5743.0                                2.8  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 0                 692.50           NaN             NaN
# 18               2564.80  2.730000e+09           35.41
# 27                743.79  3.430000e+09           21.47
# 34                139.23  2.790000e+09           14.17
# 58               7881.26  1.040000e+10           17.91
# 71               1355.68  3.620000e+09            2.99
# 110               564.26  3.290000e+09           28.25
# 122              1879.63  5.700000e+09           23.78
# 132              1058.90  2.200000e+09           12.60
# 158              5070.98  5.470000e+09           30.67
# 161               937.98  1.200000e+09           10.14
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 0                                 NaN                         257.00
# 18                      -3.730000e+08                         132.00
# 27                      -3.900000e+08                         190.36
# 34                      -2.210000e+08                         208.20
# 58                      -2.970000e+09                         131.72
# 71                      -1.530000e+08                         164.40
# 110                     -4.580000e+08                         204.74
# 122                     -8.040000e+08                         177.10
# 132                     -3.220000e+08                         197.50
# 158                     -1.010000e+09                         121.48
# 161                     -1.890000e+08                         267.00
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 0                             231.9                     257.00
# 18                            133.6                     132.00
# 27                            168.2                     190.36
# 34                            180.1                     208.20
# 58                            120.0                     131.72
# 71                            135.6                     164.40
# 110                           191.3                     204.74
# 122                           171.6                     177.10
# 132                           209.4                     197.50
# 158                           104.2                     121.48
# 161                           253.7                     267.00
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 0           5740436.0                     5.44                           22.9
# 18          3404610.8                     4.04                           40.1
# 27          2549805.5                     5.09                           18.3
# 34          2566839.0                     4.88                           25.3
# 58         12000000.0                     4.03                           16.0
# 71          2970876.5                     3.12                           33.0
# 110         3541382.5                     4.75                           30.5
# 122         7083773.0                     4.47                           34.5
# 132         2228384.0                     4.22                           16.8
# 158         4896461.5                     3.05                           41.6
# 161         2273666.0                     5.41                           40.7
#
# [11 rows x 358 columns]

# %%
df[df["Population annual growth rate (%)"] > 3.8]
# Out:
#          Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 0    Afghanistan          1          1                          151.0
# 28       Burundi         29          3                           30.0
# 100      Liberia        101          3                            NaN
# 180  Timor-Leste        181          6                           49.0
#
#      Adult literacy rate (%)  \
# 0                       28.0
# 28                      59.3
# 100                     60.0
# 180                      NaN
#
#      Gross national income per capita (PPP international $)  \
# 0                                                  NaN
# 28                                               320.0
# 100                                              260.0
# 180                                             5100.0
#
#      Net primary school enrolment ratio female (%)  \
# 0                                              NaN
# 28                                            73.0
# 100                                           39.0
# 180                                           67.0
#
#      Net primary school enrolment ratio male (%)  \
# 0                                            NaN
# 28                                          76.0
# 100                                         40.0
# 180                                         70.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 0                            26088.0                                4.0  ...
# 28                            8173.0                                3.9  ...
# 100                           3579.0                                3.9  ...
# 180                           1114.0                                4.3  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 0                 692.50           NaN             NaN
# 28                223.50   790000000.0            7.61
# 100               472.66   444000000.0            0.99
# 180                  NaN           NaN             NaN
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 0                                 NaN                          257.0
# 28                       -232000000.0                          181.3
# 100                               NaN                          143.9
# 180                               NaN                            NaN
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 0                             231.9                      257.0
# 28                            190.3                      181.3
# 100                           172.7                      143.9
# 180                             NaN                        NaN
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 0           5740436.0                     5.44                           22.9
# 28           785879.1                     6.64                           10.0
# 100         1999683.5                     4.07                           58.1
# 180               NaN                      NaN                            NaN
#
# [4 rows x 358 columns]

# %%
df[["Country", "Adult literacy rate (%)", "Population annual growth rate (%)"]] \
[(df["Population annual growth rate (%)"] > 3) & (df["Adult literacy rate (%)"]  > 60)]
# Out:
#                   Country  Adult literacy rate (%)  \
# 39       Congo, Dem. Rep.                     67.2
# 88                 Jordan                     91.1
# 147                 Qatar                     89.0
# 188                Uganda                     68.1
# 190  United Arab Emirates                     88.5
#
#      Population annual growth rate (%)
# 39                                 3.2
# 88                                 3.3
# 147                                3.1
# 188                                3.2
# 190                                3.5

# %% [markdown]
# ### indexing

# %% [markdown]
# #### indexing with iloc

# %%
state.loc["Belarus"]
df.iloc[15]      # index location gives back one specific row
# Out:
# Country                             Belarus
# CountryID                                16
# Continent                                 2
# Adolescent fertility rate (%)          22.0
# Adult literacy rate (%)                99.6
#                                     ...
# Under_five_mortality_from_IHME         10.3
# Under_five_mortality_rate              15.1
# Urban_population                  7057977.0
# Urban_population_growth                0.11
# Urban_population_pct_of_total          72.2
# Name: 15, Length: 358, dtype: object

# %%
df.iloc[15,0]    # row 16 column 1
# Out:
# 'Belarus'

# %%
df.iloc[15,-1] # row 15, last col
# Out:
# 72.2

# %%
df.iloc[23:26]
# Out:
#               Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 23           Botswana         24          3                           51.0
# 24             Brazil         25          5                           71.0
# 25  Brunei Darussalam         26          6                           31.0
#
#     Adult literacy rate (%)  \
# 23                     81.2
# 24                     88.6
# 25                     92.7
#
#     Gross national income per capita (PPP international $)  \
# 23                                            11730.0
# 24                                             8700.0
# 25                                            49900.0
#
#     Net primary school enrolment ratio female (%)  \
# 23                                           85.0
# 24                                           95.0
# 25                                           94.0
#
#     Net primary school enrolment ratio male (%)  \
# 23                                         83.0
# 24                                         93.0
# 25                                         94.0
#
#     Population (in thousands) total  Population annual growth rate (%)  ...  \
# 23                           1858.0                                1.2  ...
# 24                         189323.0                                1.3  ...
# 25                            382.0                                2.1  ...
#
#     Total_CO2_emissions  Total_income  Total_reserves  \
# 23              4554.35  8.050000e+09         1334.86
# 24            325487.78  7.380000e+11           28.72
# 25              5891.71  4.830000e+09             NaN
#
#     Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 23                      1.600000e+09                           47.3
# 24                      3.660000e+10                           25.6
# 25                               NaN                            8.8
#
#     Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 23                            39.8                       47.3
# 24                            25.5                       25.6
# 25                             7.2                        8.8
#
#     Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 23      1.053828e+06                     2.62                           57.4
# 24      1.570000e+08                     2.07                           84.2
# 25      2.747658e+05                     2.86                           73.5
#
# [3 rows x 358 columns]

# %% [markdown]
# #### indexing with loc

# %%
state = df.copy()  # copy of df
state.set_index("Country", inplace=True)  #set new index
state.head()
# Out:
#              CountryID  Continent  Adolescent fertility rate (%)  \
# Country
# Afghanistan          1          1                          151.0
# Albania              2          2                           27.0
# Algeria              3          3                            6.0
# Andorra              4          2                            NaN
# Angola               5          3                          146.0
#
#              Adult literacy rate (%)  \
# Country
# Afghanistan                     28.0
# Albania                         98.7
# Algeria                         69.9
# Andorra                          NaN
# Angola                          67.4
#
#              Gross national income per capita (PPP international $)  \
# Country
# Afghanistan                                                NaN
# Albania                                                 6000.0
# Algeria                                                 5940.0
# Andorra                                                    NaN
# Angola                                                  3890.0
#
#              Net primary school enrolment ratio female (%)  \
# Country
# Afghanistan                                            NaN
# Albania                                               93.0
# Algeria                                               94.0
# Andorra                                               83.0
# Angola                                                49.0
#
#              Net primary school enrolment ratio male (%)  \
# Country
# Afghanistan                                          NaN
# Albania                                             94.0
# Algeria                                             96.0
# Andorra                                             83.0
# Angola                                              51.0
#
#              Population (in thousands) total  \
# Country
# Afghanistan                          26088.0
# Albania                               3172.0
# Algeria                              33351.0
# Andorra                                 74.0
# Angola                               16557.0
#
#              Population annual growth rate (%)  Population in urban areas (%)  \
# Country
# Afghanistan                                4.0                           23.0
# Albania                                    0.6                           46.0
# Algeria                                    1.5                           64.0
# Andorra                                    1.0                           93.0
# Angola                                     2.8                           54.0
#
#              ...  Total_CO2_emissions  Total_income  Total_reserves  \
# Country      ...
# Afghanistan  ...               692.50           NaN             NaN
# Albania      ...              3499.12  4.790000e+09           78.14
# Algeria      ...            137535.56  6.970000e+10          351.36
# Andorra      ...                  NaN           NaN             NaN
# Angola       ...              8991.46  1.490000e+10           27.13
#
#              Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# Country
# Afghanistan                               NaN                         257.00
# Albania                         -2.040000e+09                          18.47
# Algeria                          4.700000e+09                          40.00
# Andorra                                   NaN                            NaN
# Angola                           9.140000e+09                         164.10
#
#              Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# Country
# Afghanistan                           231.9                     257.00
# Albania                                15.5                      18.47
# Algeria                                31.2                      40.00
# Andorra                                 NaN                        NaN
# Angola                                242.5                     164.10
#
#              Urban_population  Urban_population_growth  \
# Country
# Afghanistan         5740436.0                     5.44
# Albania             1431793.9                     2.21
# Algeria            20800000.0                     2.61
# Andorra                   NaN                      NaN
# Angola              8578749.0                     4.14
#
#              Urban_population_pct_of_total
# Country
# Afghanistan                           22.9
# Albania                               45.4
# Algeria                               63.3
# Andorra                                NaN
# Angola                                53.3
#
# [5 rows x 357 columns]

# %% [markdown]
# ## Statistics
# Use these commands to perform various statistical tests. (These can all be applied to a series as well.)

# %%
df.describe()                                       # Summary statistics for numerical columns
df.mean()                                       # Returns the mean of all columns
df.corr()                                       # Returns the correlation between columns in a DataFrame
df.count()                                      # Returns the number of non-null values in each DataFrame column
df.max()                                        # Returns the highest value in each column
df.min()                                        # Returns the lowest value in each column
df.median()                                     # Returns the median of each column
df.std()                                        # Returns the standard deviation of each column

# %%
df = pd.read_csv("../data/WHO.csv")
df.head()  # df.tail()
# Out:
#        Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 0  Afghanistan          1          1                          151.0
# 1      Albania          2          2                           27.0
# 2      Algeria          3          3                            6.0
# 3      Andorra          4          2                            NaN
# 4       Angola          5          3                          146.0
#
#    Adult literacy rate (%)  \
# 0                     28.0
# 1                     98.7
# 2                     69.9
# 3                      NaN
# 4                     67.4
#
#    Gross national income per capita (PPP international $)  \
# 0                                                NaN
# 1                                             6000.0
# 2                                             5940.0
# 3                                                NaN
# 4                                             3890.0
#
#    Net primary school enrolment ratio female (%)  \
# 0                                            NaN
# 1                                           93.0
# 2                                           94.0
# 3                                           83.0
# 4                                           49.0
#
#    Net primary school enrolment ratio male (%)  \
# 0                                          NaN
# 1                                         94.0
# 2                                         96.0
# 3                                         83.0
# 4                                         51.0
#
#    Population (in thousands) total  Population annual growth rate (%)  ...  \
# 0                          26088.0                                4.0  ...
# 1                           3172.0                                0.6  ...
# 2                          33351.0                                1.5  ...
# 3                             74.0                                1.0  ...
# 4                          16557.0                                2.8  ...
#
#    Total_CO2_emissions  Total_income  Total_reserves  \
# 0               692.50           NaN             NaN
# 1              3499.12  4.790000e+09           78.14
# 2            137535.56  6.970000e+10          351.36
# 3                  NaN           NaN             NaN
# 4              8991.46  1.490000e+10           27.13
#
#    Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 0                               NaN                         257.00
# 1                     -2.040000e+09                          18.47
# 2                      4.700000e+09                          40.00
# 3                               NaN                            NaN
# 4                      9.140000e+09                         164.10
#
#    Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 0                           231.9                     257.00
# 1                            15.5                      18.47
# 2                            31.2                      40.00
# 3                             NaN                        NaN
# 4                           242.5                     164.10
#
#    Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 0         5740436.0                     5.44                           22.9
# 1         1431793.9                     2.21                           45.4
# 2        20800000.0                     2.61                           63.3
# 3               NaN                      NaN                            NaN
# 4         8578749.0                     4.14                           53.3
#
# [5 rows x 358 columns]

# %% [markdown]
# ### describe

# %%
df.describe().round(2)
# Out:
#        CountryID  Continent  Adolescent fertility rate (%)  \
# count     202.00     202.00                         177.00
# mean      101.50       3.58                          59.46
# std        58.46       1.81                          49.11
# min         1.00       1.00                           0.00
# 25%        51.25       2.00                          19.00
# 50%       101.50       3.00                          46.00
# 75%       151.75       5.00                          91.00
# max       202.00       7.00                         199.00
#
#        Adult literacy rate (%)  \
# count                   131.00
# mean                     78.87
# std                      20.42
# min                      23.60
# 25%                      68.40
# 50%                      86.50
# 75%                      95.30
# max                      99.80
#
#        Gross national income per capita (PPP international $)  \
# count                                             178.00
# mean                                            11250.11
# std                                             12586.75
# min                                               260.00
# 25%                                              2112.50
# 50%                                              6175.00
# 75%                                             14502.50
# max                                             60870.00
#
#        Net primary school enrolment ratio female (%)  \
# count                                         179.00
# mean                                           84.03
# std                                            17.79
# min                                             6.00
# 25%                                            79.00
# 50%                                            90.00
# 75%                                            96.00
# max                                           100.00
#
#        Net primary school enrolment ratio male (%)  \
# count                                       179.00
# mean                                         85.70
# std                                          15.45
# min                                          11.00
# 25%                                          79.50
# 50%                                          90.00
# 75%                                          96.00
# max                                         100.00
#
#        Population (in thousands) total  Population annual growth rate (%)  \
# count                           193.00                             193.00
# mean                          34098.05                               1.30
# std                          130495.73                               1.16
# min                               2.00                              -2.50
# 25%                            1340.00                               0.50
# 50%                            6762.00                               1.30
# 75%                           21732.00                               2.10
# max                         1328474.00                               4.30
#
#        Population in urban areas (%)  ...  Total_CO2_emissions  Total_income  \
# count                         193.00  ...               186.00  1.780000e+02
# mean                           54.91  ...            148359.55  2.015567e+11
# std                            23.55  ...            613309.10  9.400689e+11
# min                            10.00  ...                25.65  5.190000e+07
# 25%                            36.00  ...              1672.62  3.317500e+09
# 50%                            57.00  ...             10211.56  1.145000e+10
# 75%                            73.00  ...             65492.17  8.680000e+10
# max                           100.00  ...           5776431.50  1.100000e+13
#
#        Total_reserves  Trade_balance_goods_and_services  \
# count          128.00                      1.710000e+02
# mean            57.25                      3.424012e+08
# std            138.67                      5.943043e+10
# min              0.99                     -7.140000e+11
# 25%             16.29                     -1.210000e+09
# 50%             28.52                     -2.240000e+08
# 75%             55.31                      1.024000e+09
# max           1334.86                      1.390000e+11
#
#        Under_five_mortality_from_CME  Under_five_mortality_from_IHME  \
# count                         181.00                          170.00
# mean                           56.68                           54.36
# std                            60.06                           61.16
# min                             2.90                            3.00
# 25%                            12.40                            8.48
# 50%                            29.98                           27.60
# 75%                            88.70                           82.90
# max                           267.00                          253.70
#
#        Under_five_mortality_rate  Urban_population  Urban_population_growth  \
# count                     181.00      1.880000e+02                   188.00
# mean                       56.68      1.665763e+07                     2.17
# std                        60.06      5.094867e+07                     1.60
# min                         2.90      1.545600e+04                    -1.16
# 25%                        12.40      9.171623e+05                     1.10
# 50%                        29.98      3.427661e+06                     1.94
# 75%                        88.70      9.837113e+06                     3.25
# max                       267.00      5.270000e+08                     7.85
#
#        Urban_population_pct_of_total
# count                         188.00
# mean                           55.20
# std                            23.74
# min                            10.00
# 25%                            35.65
# 50%                            57.30
# 75%                            72.75
# max                           100.00
#
# [8 rows x 357 columns]

# %%
df.describe(include="object") # summary stat on non-floats
# Out:
#             Country
# count           202
# unique          202
# top     Afghanistan
# freq              1

# %%
df.value_counts("Continent")
# Out:
# Continent
# 2    51
# 3    48
# 6    35
# 5    31
# 1    21
# 7     9
# 4     7
# dtype: int64

# %%
import seaborn as sns
sns.countplot(data=df, x=df.Continent, order=[1, 2, 3, 4, 5, 6, 7]);

# %% [markdown]
# ## Reshaping Data – Change the layout of a data set

# %% [markdown]
# ### melt

# %%
pd.melt(df2)  # Gather columns into rows.
# Out:
#   variable  value
# 0        a      1
# 1        a      4
# 2        a      7
# 3        b      2
# 4        b      5
# 5        b      8
# 6        c      3
# 7        c      6
# 8        c      9

# %% [markdown]
# ### concat

# %%
df4 = pd.concat([df1,df2])    # Append rows of DataFrames
df4
# Out:
#    a  b  c
# 1  1  2  3
# 2  4  5  6
# 3  7  8  9
# 1  1  2  3
# 2  4  5  6
# 3  7  8  9

# %% [markdown]
# ### sort_values

# %%
df4.sort_values('b')    # Order rows by values of a column (low to high).
# Out:
#    a  b  c
# 1  1  2  3
# 1  1  2  3
# 2  4  5  6
# 2  4  5  6
# 3  7  8  9
# 3  7  8  9

# %% [markdown]
# ### rename

# %%
df5 = df4.rename(columns = {'b':'col2'})   # Rename the columns of a DataFrame
df5.head()
# Out:
#    a  col2  c
# 1  1     2  3
# 2  4     5  6
# 3  7     8  9
# 1  1     2  3
# 2  4     5  6

# %% [markdown]
# ### drop_duplicates

# %%
df5.drop_duplicates()
# Out:
#    a  col2  c
# 1  1     2  3
# 2  4     5  6
# 3  7     8  9

# %%
state2 = state.copy()
state2
# Out:
#                     CountryID  Continent  Adolescent fertility rate (%)  \
# Country
# Afghanistan                 1          1                          151.0
# Albania                     2          2                           27.0
# Algeria                     3          3                            6.0
# Andorra                     4          2                            NaN
# Angola                      5          3                          146.0
# ...                       ...        ...                            ...
# Vietnam                   198          6                           25.0
# West Bank and Gaza        199          1                            NaN
# Yemen                     200          1                           83.0
# Zambia                    201          3                          161.0
# Zimbabwe                  202          3                          101.0
#
#                     Adult literacy rate (%)  \
# Country
# Afghanistan                            28.0
# Albania                                98.7
# Algeria                                69.9
# Andorra                                 NaN
# Angola                                 67.4
# ...                                     ...
# Vietnam                                90.3
# West Bank and Gaza                      NaN
# Yemen                                  54.1
# Zambia                                 68.0
# Zimbabwe                               89.5
#
#                     Gross national income per capita (PPP international $)  \
# Country
# Afghanistan                                                       NaN
# Albania                                                        6000.0
# Algeria                                                        5940.0
# Andorra                                                           NaN
# Angola                                                         3890.0
# ...                                                               ...
# Vietnam                                                        2310.0
# West Bank and Gaza                                                NaN
# Yemen                                                          2090.0
# Zambia                                                         1140.0
# Zimbabwe                                                          NaN
#
#                     Net primary school enrolment ratio female (%)  \
# Country
# Afghanistan                                                   NaN
# Albania                                                      93.0
# Algeria                                                      94.0
# Andorra                                                      83.0
# Angola                                                       49.0
# ...                                                           ...
# Vietnam                                                      91.0
# West Bank and Gaza                                            NaN
# Yemen                                                        65.0
# Zambia                                                       94.0
# Zimbabwe                                                     88.0
#
#                     Net primary school enrolment ratio male (%)  \
# Country
# Afghanistan                                                 NaN
# Albania                                                    94.0
# Algeria                                                    96.0
# Andorra                                                    83.0
# Angola                                                     51.0
# ...                                                         ...
# Vietnam                                                    96.0
# West Bank and Gaza                                          NaN
# Yemen                                                      85.0
# Zambia                                                     90.0
# Zimbabwe                                                   87.0
#
#                     Population (in thousands) total  \
# Country
# Afghanistan                                 26088.0
# Albania                                      3172.0
# Algeria                                     33351.0
# Andorra                                        74.0
# Angola                                      16557.0
# ...                                             ...
# Vietnam                                     86206.0
# West Bank and Gaza                              NaN
# Yemen                                       21732.0
# Zambia                                      11696.0
# Zimbabwe                                    13228.0
#
#                     Population annual growth rate (%)  \
# Country
# Afghanistan                                       4.0
# Albania                                           0.6
# Algeria                                           1.5
# Andorra                                           1.0
# Angola                                            2.8
# ...                                               ...
# Vietnam                                           1.4
# West Bank and Gaza                                NaN
# Yemen                                             3.0
# Zambia                                            1.9
# Zimbabwe                                          0.8
#
#                     Population in urban areas (%)  ...  Total_income  \
# Country                                            ...
# Afghanistan                                  23.0  ...           NaN
# Albania                                      46.0  ...  4.790000e+09
# Algeria                                      64.0  ...  6.970000e+10
# Andorra                                      93.0  ...           NaN
# Angola                                       54.0  ...  1.490000e+10
# ...                                           ...  ...           ...
# Vietnam                                      27.0  ...  4.480000e+10
# West Bank and Gaza                            NaN  ...  3.780000e+09
# Yemen                                        28.0  ...  1.150000e+10
# Zambia                                       35.0  ...  4.090000e+09
# Zimbabwe                                     36.0  ...  5.620000e+09
#
#                     Total_reserves  Trade_balance_goods_and_services  \
# Country
# Afghanistan                    NaN                               NaN
# Albania                      78.14                     -2.040000e+09
# Algeria                     351.36                      4.700000e+09
# Andorra                        NaN                               NaN
# Angola                       27.13                      9.140000e+09
# ...                            ...                               ...
# Vietnam                      47.11                     -1.940000e+09
# West Bank and Gaza             NaN                               NaN
# Yemen                       114.52                      8.310000e+08
# Zambia                       10.41                     -4.470000e+08
# Zimbabwe                      3.39                     -1.710000e+08
#
#                     Under_five_mortality_from_CME  \
# Country
# Afghanistan                                257.00
# Albania                                     18.47
# Algeria                                     40.00
# Andorra                                       NaN
# Angola                                     164.10
# ...                                           ...
# Vietnam                                     20.20
# West Bank and Gaza                          28.00
# Yemen                                       82.40
# Zambia                                     175.30
# Zimbabwe                                   106.50
#
#                     Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# Country
# Afghanistan                                  231.9                     257.00
# Albania                                       15.5                      18.47
# Algeria                                       31.2                      40.00
# Andorra                                        NaN                        NaN
# Angola                                       242.5                     164.10
# ...                                            ...                        ...
# Vietnam                                       23.4                      20.20
# West Bank and Gaza                            25.8                      28.00
# Yemen                                         87.9                      82.40
# Zambia                                       163.8                     175.30
# Zimbabwe                                      67.0                     106.50
#
#                     Urban_population  Urban_population_growth  \
# Country
# Afghanistan                5740436.0                     5.44
# Albania                    1431793.9                     2.21
# Algeria                   20800000.0                     2.61
# Andorra                          NaN                      NaN
# Angola                     8578749.0                     4.14
# ...                              ...                      ...
# Vietnam                   21900000.0                     2.90
# West Bank and Gaza         2596216.0                     3.33
# Yemen                      5759120.5                     4.37
# Zambia                     4017411.0                     1.95
# Zimbabwe                   4709965.0                     1.90
#
#                     Urban_population_pct_of_total  \
# Country
# Afghanistan                                  22.9
# Albania                                      45.4
# Algeria                                      63.3
# Andorra                                       NaN
# Angola                                       53.3
# ...                                           ...
# Vietnam                                      26.4
# West Bank and Gaza                           71.6
# Yemen                                        27.3
# Zambia                                       35.0
# Zimbabwe                                     35.9
#
#                     Average poulation growth rate in %
# Country
# Afghanistan                                        NaN
# Albania                                            NaN
# Algeria                                            NaN
# Andorra                                            NaN
# Angola                                             NaN
# ...                                                ...
# Vietnam                                            NaN
# West Bank and Gaza                                 NaN
# Yemen                                              NaN
# Zambia                                             NaN
# Zimbabwe                                           NaN
#
# [202 rows x 358 columns]

# %%
state2["Continent"].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %% [markdown]
# ### group_by

# %%
pop_growth_continent = state2["Population annual growth rate (%)"].groupby("Continent").mean()
pop_growth_continent = pd.DataFrame(pop_growth_continent)
pop_growth_continent
# todo rename Continents
# Out:
#            Population annual growth rate (%)
# Continent
# 1                                   2.190000
# 2                                   0.282353
# 3                                   2.277083
# 4                                   0.950000
# 5                                   1.134483
# 6                                   1.033333
# 7                                   1.488889

# %% [markdown]
# ## date range

# %%
import pandas as pd
dates = pd.date_range("20220227", periods=10)
print(pd.DataFrame(dates))
# Out:
#            0
# 0 2022-02-27
# 1 2022-02-28
# 2 2022-03-01
# 3 2022-03-02
# 4 2022-03-03
# 5 2022-03-04
# 6 2022-03-05
# 7 2022-03-06
# 8 2022-03-07
# 9 2022-03-08

# %% [markdown]
# ## to_numpy

# %%
dates.to_numpy()
# Out:
# array(['2022-02-27T00:00:00.000000000', '2022-02-28T00:00:00.000000000',
#        '2022-03-01T00:00:00.000000000', '2022-03-02T00:00:00.000000000',
#        '2022-03-03T00:00:00.000000000', '2022-03-04T00:00:00.000000000',
#        '2022-03-05T00:00:00.000000000', '2022-03-06T00:00:00.000000000',
#        '2022-03-07T00:00:00.000000000', '2022-03-08T00:00:00.000000000'],
#       dtype='datetime64[ns]')
